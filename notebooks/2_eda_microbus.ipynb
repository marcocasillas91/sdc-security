# %% [markdown]
# # EDA for theft inside **microbus** units in CDMX
# This notebook explores how many rows of data can be extracted for a data subset that focuses on the issue of thefts in public transportation units called **microbuses** or **peseros** reported for CDMX. This is a insecurity topic that the city has not been able to control yet

# %%
import pandas as pd
import zipfile
import numpy as np
import matplotlib.pyplot as plt

#Path
#Insert your local repo path to file 
repo_path = "INSERT YOUR LOCAL SDC-SECURITY REPO PATH HERE"
repo_path = "D:\Archivos\Social Data Challenge\sdc-security"

# %%
crimes= pd.read_csv(repo_path+'\datasets\crimes.csv')

# %%
crimes.head()
# Out:
#    idcarpeta  anio_inicio  mes_inicio fechainicio  \
# 0    8324429         2019           1  2019-01-04
# 1    8324430         2019           1  2019-01-04
# 2    8324431         2019           1  2019-01-04
# 3    8324435         2019           1  2019-01-04
# 4    8324438         2019           1  2019-01-04
#
#                                               delito  \
# 0                                             FRAUDE
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2  ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLE...
# 3  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4                  ROBO DE MOTOCICLETA SIN VIOLENCIA
#
#                                            categoria       sexo  edad  \
# 0                             DELITO DE BAJO IMPACTO  Masculino    62
# 1                             DELITO DE BAJO IMPACTO   Femenino    38
# 2  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino    42
# ...

# %%
categorias = crimes.categoria.unique()
print(categorias)
# Out:
# ['DELITO DE BAJO IMPACTO'
#  'ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON VIOLENCIA'
#  'ROBO DE VEHÍCULO CON Y SIN VIOLENCIA' 'VIOLACIÓN'
#  'ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN VIOLENCIA'
#  'ROBO A PASAJERO A BORDO DEL METRO CON Y SIN VIOLENCIA'
#  'LESIONES DOLOSAS POR DISPARO DE ARMA DE FUEGO'
#  'ROBO A NEGOCIO CON VIOLENCIA' 'HECHO NO DELICTIVO'
#  'ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIOLENCIA' 'HOMICIDIO DOLOSO'
#  'ROBO A REPARTIDOR CON Y SIN VIOLENCIA'
#  'ROBO A CASA HABITACIÓN CON VIOLENCIA'
#  'ROBO A PASAJERO A BORDO DE TAXI CON VIOLENCIA' 'SECUESTRO'
#  'ROBO A TRANSPORTISTA CON Y SIN VIOLENCIA']

# %%
microbus=crimes[crimes["categoria"] == "ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN VIOLENCIA"]

# %%
print(microbus.shape)
microbus.head()
# Out:
# (3037, 21)
#      idcarpeta  anio_inicio  mes_inicio fechainicio  \
# 10     8324459         2019           1  2019-01-04
# 51     8324621         2019           1  2019-01-04
# 187    8325175         2019           1  2019-01-05
# 264    8325471         2019           1  2019-01-05
# 540    8326537         2019           1  2019-01-07
#
#                                                 delito  \
# 10   ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CO...
# 51   ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CO...
# 187  ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CO...
# 264  ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CO...
# 540  ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CO...
#
#                                              categoria       sexo  edad  \
# 10   ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN ...  Masculino    27
# 51   ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN ...  Masculino    40
# 187  ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN ...   Femenino    30
# ...

# %%
crimes.categoria.unique()
# Out:
# array(['DELITO DE BAJO IMPACTO',
#        'ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON VIOLENCIA',
#        'ROBO DE VEHÍCULO CON Y SIN VIOLENCIA', 'VIOLACIÓN',
#        'ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN VIOLENCIA',
#        'ROBO A PASAJERO A BORDO DEL METRO CON Y SIN VIOLENCIA',
#        'LESIONES DOLOSAS POR DISPARO DE ARMA DE FUEGO',
#        'ROBO A NEGOCIO CON VIOLENCIA', 'HECHO NO DELICTIVO',
#        'ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIOLENCIA',
#        'HOMICIDIO DOLOSO', 'ROBO A REPARTIDOR CON Y SIN VIOLENCIA',
#        'ROBO A CASA HABITACIÓN CON VIOLENCIA',
#        'ROBO A PASAJERO A BORDO DE TAXI CON VIOLENCIA', 'SECUESTRO',
#        'ROBO A TRANSPORTISTA CON Y SIN VIOLENCIA'], dtype=object)
